# %%
import ytfinance as yf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import ytfinance as yf
#
# ModuleNotFoundError: No module named 'ytfinance'

# %%
import talib

# %%
import yfinance as yf

# %%
reliance = yf.download("RELIANCE.NS",
    period="1y",
    interval="1d")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
print(reliance)
# Out:
# Price             Close         High          Low         Open      Volume
# Ticker      RELIANCE.NS  RELIANCE.NS  RELIANCE.NS  RELIANCE.NS RELIANCE.NS
# Date
# 2025-02-03  1240.943848  1251.003646  1232.627088  1246.023536     9252345
# 2025-02-04  1280.087402  1283.673179  1241.640978  1243.085283    16691069
# 2025-02-05  1273.115234  1285.366353  1271.621201  1277.547605    10112028
# 2025-02-06  1276.452026  1282.876320  1265.296507  1268.633156     9956001
# 2025-02-07  1261.661011  1278.593385  1256.979756  1271.073492     8764283
# ...                 ...          ...          ...          ...         ...
# 2026-01-27  1380.500000  1391.599976  1368.000000  1380.000000    26302396
# 2026-01-28  1396.699951  1409.900024  1384.900024  1385.000000    11121657
# 2026-01-29  1391.000000  1402.900024  1384.000000  1402.900024    20846683
# 2026-01-30  1395.400024  1398.000000  1378.500000  1382.599976    11239835
# ...

# %%
import pandas-ta as ta
# Out:
#   Cell In[13], line 1
#     import pandas-ta as ta
#                  ^
# SyntaxError: invalid syntax

# %%
python -c "import pandas_ta as ta; print(ta.version)"
# Out:
#   Cell In[14], line 1
#     python -c "import pandas_ta as ta; print(ta.version)"
#               ^
# SyntaxError: invalid syntax

# %%
pip install pandas-ta
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas_ta as ta
# Out:
# /home/prasenjit/anaconda3/envs/pytrade_env/lib/python3.11/site-packages/pandas_ta/__init__.py:7: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import get_distribution, DistributionNotFound

# %%
print(reliance)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(reliance)
#
# NameError: name 'reliance' is not defined

# %%
import yfinance as yf
import pandas_ta as ta
df = yf.download("RELIANCE.NS",
    period="1y",
    interval="1d")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
print(df)
# Out:
# Price             Close         High          Low         Open      Volume
# Ticker      RELIANCE.NS  RELIANCE.NS  RELIANCE.NS  RELIANCE.NS RELIANCE.NS
# Date
# 2025-02-03  1240.943848  1251.003646  1232.627088  1246.023536     9252345
# 2025-02-04  1280.087402  1283.673179  1241.640978  1243.085283    16691069
# 2025-02-05  1273.115234  1285.366353  1271.621201  1277.547605    10112028
# 2025-02-06  1276.452026  1282.876320  1265.296507  1268.633156     9956001
# 2025-02-07  1261.661011  1278.593385  1256.979756  1271.073492     8764283
# ...                 ...          ...          ...          ...         ...
# 2026-01-27  1380.500000  1391.599976  1368.000000  1380.000000    26302396
# 2026-01-28  1396.699951  1409.900024  1384.900024  1385.000000    11121657
# 2026-01-29  1391.000000  1402.900024  1384.000000  1402.900024    20846683
# 2026-01-30  1395.400024  1398.000000  1378.500000  1382.599976    11239835
# ...

# %%
tolerance = 0.002  # 0.1% difference
df['Doji'] = abs(df['Open'] - df['Close']) <= (df['Close'] * tolerance)
print(df.drop)
# Out:
# <bound method DataFrame.drop of Price             Close         High          Low         Open      Volume  \
# Ticker      RELIANCE.NS  RELIANCE.NS  RELIANCE.NS  RELIANCE.NS RELIANCE.NS
# Date
# 2025-02-03  1240.943848  1251.003646  1232.627088  1246.023536     9252345
# 2025-02-04  1280.087402  1283.673179  1241.640978  1243.085283    16691069
# 2025-02-05  1273.115234  1285.366353  1271.621201  1277.547605    10112028
# 2025-02-06  1276.452026  1282.876320  1265.296507  1268.633156     9956001
# 2025-02-07  1261.661011  1278.593385  1256.979756  1271.073492     8764283
# ...                 ...          ...          ...          ...         ...
# 2026-01-27  1380.500000  1391.599976  1368.000000  1380.000000    26302396
# 2026-01-28  1396.699951  1409.900024  1384.900024  1385.000000    11121657
# 2026-01-29  1391.000000  1402.900024  1384.000000  1402.900024    20846683
# 2026-01-30  1395.400024  1398.000000  1378.500000  1382.599976    11239835
# ...
